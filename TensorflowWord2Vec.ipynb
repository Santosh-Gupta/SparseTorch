# %% [markdown]
# <a href="https://colab.research.google.com/github/Santosh-Gupta/SparseTorch/blob/master/TensorflowWord2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import collections
import hashlib
import math
import os
import random
import sys
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector

data_index = 0

# %%
def _hash_file(fpath):
  hasher = hashlib.sha256()
  with open(fpath, 'rb') as fpath_file:
    for chunk in iter(lambda: fpath_file.read(65535), b''):
      hasher.update(chunk)
  return hasher.hexdigest()

# %%
  # Create the directory for TensorBoard variables if there is not.
  if not os.path.exists('log_dir'):
    os.makedirs('log_dir')

  # Step 1: Download the data.
  # Note: Source website does not support HTTPS right now.
  url = 'http://mattmahoney.net/dc/'

  # pylint: disable=redefined-outer-name
  def maybe_download(filename, expected_bytes, sha256=None):
    """Download a file if not present, and make sure it's the right size."""
    local_filename = os.path.join(gettempdir(), filename)
    if not os.path.exists(local_filename):
      local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                     local_filename)
    statinfo = os.stat(local_filename)

    if sha256 and _hash_file(local_filename) != sha256:
      raise Exception('Failed to verify ' + local_filename + ' due to hash '
                      'mismatch. Can you get to it with a browser?')

    if statinfo.st_size == expected_bytes:
      print('Found and verified', filename)
    else:
      print(statinfo.st_size)
      raise Exception('Failed to verify ' + local_filename +
                      '. Can you get to it with a browser?')
    return local_filename

# %%
filename = maybe_download(
    'text8.zip',
    31344016,
    sha256='a6640522afe85d1963ad56c05b0ede0a0c000dddc9671758a6cc09b7a38e5232')
# Out:
# Found and verified text8.zip

# %%
 # Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
      data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
# Out:
# Data size 17005207

# %%
def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = {}
    for word, _ in count:
      dictionary[word] = len(dictionary)
    data = []
    unk_count = 0
    for word in words:
      index = dictionary.get(word, 0)
      if index == 0:  # dictionary['UNK']
        unk_count += 1
      data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
  # Filling 4 global variables:
  # data - list of codes (integers from 0 to vocabulary_size-1).
  #   This is the original text but words are replaced by their codes
  # count - map of words(strings) to count of occurrences
  # dictionary - map of words(strings) to their codes(integers)
  # reverse_dictionary - maps codes(integers) to words(strings)
data, count, unused_dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
	  # Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
    if data_index + span > len(data):
      data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
      context_words = [w for w in range(span) if w != skip_window]
      words_to_use = random.sample(context_words, num_skips)
      for j, context_word in enumerate(words_to_use):
        batch[i * num_skips + j] = buffer[skip_window]
        labels[i * num_skips + j, 0] = buffer[context_word]
      if data_index == len(data):
        buffer.extend(data[0:span])
        data_index = span
      else:
        buffer.append(data[data_index])
        data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
  # Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit
# the validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

    # Input data.
    with tf.name_scope('inputs'):
      train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
      train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
      valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
      # Look up embeddings for inputs.
      with tf.name_scope('embeddings'):
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

      # Construct the variables for the NCE loss
      with tf.name_scope('weights'):
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
      with tf.name_scope('biases'):
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]), trainable = False)

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    # Explanation of the meaning of NCE loss:
    #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
    with tf.name_scope('loss'):
      loss = tf.reduce_mean(
          tf.nn.nce_loss(
              weights=nce_weights,
              biases=nce_biases,
              labels=train_labels,
              inputs=embed,
              num_sampled=num_sampled,
              num_classes=vocabulary_size))

    # Add the loss value as a scalar to summary.
    tf.summary.scalar('loss', loss)

    # Construct the SGD optimizer using a learning rate of 1.0.
    with tf.name_scope('optimizer'):
      optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all
    # embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                              valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Merge all summaries.
    merged = tf.summary.merge_all()

    # Add variable initializer.
    init = tf.global_variables_initializer()

    # Create a saver.
    saver = tf.train.Saver()

# %%
  # Step 5: Begin training.
  num_steps = 200001

  with tf.compat.v1.Session(graph=graph) as session:
    # Open a writer to write summaries.
    writer = tf.summary.FileWriter('log_dir', session.graph)

    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')

    average_loss = 0
    for step in xrange(num_steps):
      batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                  skip_window)
      feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

      # Define metadata variable.
      run_metadata = tf.RunMetadata()

      # We perform one update step by evaluating the optimizer op (including it
      # in the list of returned values for session.run()
      # Also, evaluate the merged op to get all summaries from the returned
      # "summary" variable. Feed metadata variable to session for visualizing
      # the graph in TensorBoard.
      _, summary, loss_val = session.run([optimizer, merged, loss],
                                         feed_dict=feed_dict,
                                         run_metadata=run_metadata)
      average_loss += loss_val

      # Add returned summaries to writer in each step.
      writer.add_summary(summary, step)
      # Add metadata to visualize the graph for the last run.
      if step == (num_steps - 1):
        writer.add_run_metadata(run_metadata, 'step%d' % step)

      if step % 2000 == 0:
        if step > 0:
          average_loss /= 2000
        # The average loss is an estimate of the loss over the last 2000
        # batches.
        print('Average loss at step ', step, ': ', average_loss)
        average_loss = 0

      # Note that this is expensive (~20% slowdown if computed every 500 steps)
      if step % 10000 == 0:
        sim = similarity.eval()
        for i in xrange(valid_size):
          valid_word = reverse_dictionary[valid_examples[i]]
          top_k = 8  # number of nearest neighbors
          nearest = (-sim[i, :]).argsort()[1:top_k + 1]
          log_str = 'Nearest to %s:' % valid_word
          for k in xrange(top_k):
            close_word = reverse_dictionary[nearest[k]]
            log_str = '%s %s,' % (log_str, close_word)
          print(log_str)
    final_embeddings = normalized_embeddings.eval()

    # Write corresponding labels for the embeddings.
    with open('log_dir' + '/metadata.tsv', 'w') as f:
      for i in xrange(vocabulary_size):
        f.write(reverse_dictionary[i] + '\n')

    # Save the model for checkpoints.
    saver.save(session, os.path.join('log_dir', 'model.ckpt'))

    # Create a configuration for visualizing embeddings with the labels in
    # TensorBoard.
    config = projector.ProjectorConfig()
    embedding_conf = config.embeddings.add()
    embedding_conf.tensor_name = embeddings.name
    embedding_conf.metadata_path = os.path.join('log_dir', 'metadata.tsv')
    projector.visualize_embeddings(writer, config)

  writer.close()
# Out:
# Initialized
# Average loss at step  0 :  299.6239318847656
# Nearest to than: stopover, hallelujah, bourdieu, ugandan, traitors, randell, landforms, migrants,
# Nearest to nine: reliability, brighter, frustrating, perpendicularly, canova, finns, checker, grazing,
# Nearest to of: bloodstream, diagram, annotated, messaging, freehold, carrion, reincorporated, putin,
# Nearest to known: breda, bonneville, manager, misfits, mixers, competent, annunzio, shiloh,
# Nearest to seven: chambre, cheering, shut, slower, electoral, mont, plundered, revered,
# Nearest to but: anticommunist, loved, avenged, calorimeter, twinning, platz, autodesk, grapheme,
# Nearest to had: widgery, llu, contraindicated, consumer, cobe, northern, wolfe, dogmatically,
# Nearest to the: unaffiliated, spratly, raining, lomax, sinatra, sickle, charms, nagel,
# Nearest to one: australasian, sidewalks, mathrm, kl, tautology, saar, inc, intriguing,
# Nearest to war: so, crows, multiplied, shipment, electress, lysine, payton, breeze,
# Nearest to not: mary, phased, hutchins, barred, deviate, gdr, poulsen, injury,
# Nearest to was: assyrians, furigana, midrashic, drexler, relationship, absolutive, malone, parody,
# Nearest to system: niggle, kaliningrad, point, auras, simplifying, residency, poland, kilowatts,
# Nearest to only: fad, pectoral, monarchists, enfants, hyllus, tiers, hagiography, motherhood,
# Nearest to he: hunter, bars, terminally, dependencies, vig, dicotyledons, tollens, guatemalan,
# Nearest to while: larson, stadt, lvaro, players, dtft, correction, gormenghast, coursing,
# Average loss at step  2000 :  121.9747358083725
# Average loss at step  4000 :  58.22227988672257
# Average loss at step  6000 :  39.211077506780626
# Average loss at step  8000 :  25.83134096121788
# Average loss at step  10000 :  19.616938684225083
# Nearest to than: modula, hypertext, in, barb, dod, at, algol, pdp,
# Nearest to nine: eight, mpeg, algebraic, zero, fricative, oracle, portable, apical,
# Nearest to of: and, in, for, fricative, with, fick, modula, barb,
# Nearest to known: endogenous, coordinators, hamiltonian, defect, adaptive, fricative, algol, barb,
# Nearest to seven: zero, nine, algebraic, fricative, five, osi, portable, eight,
# Nearest to but: mushrooms, dod, masturbation, fricative, loach, irda, astbury, and,
# Nearest to had: was, ada, algol, micron, dod, amd, meta, northern,
# Nearest to the: a, mpeg, and, mvs, this, fricative, adaptive, algebraic,
# Nearest to one: two, algebraic, fricative, algol, mpeg, pdp, modula, nine,
# Nearest to war: barb, modula, portable, synthesizers, so, valuation, tetra, specimens,
# Nearest to not: zilog, dod, ast, mary, that, barred, sweeteners, algorithmic,
# Nearest to was: is, modula, has, fricative, gv, portable, folk, by,
# Nearest to system: molds, fricative, delta, follies, mpeg, sacr, mushrooms, traded,
# Nearest to only: algebraic, relational, fad, fleetwood, oracle, vault, exec, hue,
# Nearest to he: portable, barb, exec, mushrooms, amd, it, piston, zilog,
# Nearest to while: algebraic, zilog, striping, ims, dtft, baffin, mos, br,
# Average loss at step  12000 :  15.595824897527695
# Average loss at step  14000 :  12.366257693409919
# Average loss at step  16000 :  10.86453917992115
# Average loss at step  18000 :  10.137433400169014
# Average loss at step  20000 :  9.233331260442734
# Nearest to than: for, modula, stadtbahn, in, dod, hypertext, barb, rgermeister,
# Nearest to nine: eight, four, six, five, seven, zero, three, fricative,
# Nearest to of: and, in, for, with, or, fricative, glas, stadtbahn,
# Nearest to known: greenhouses, such, well, endogenous, threonine, rgermeister, coordinators, glas,
# Nearest to seven: eight, four, three, five, nine, zero, six, one,
# Nearest to but: and, mushrooms, glas, dod, fricative, goitre, irda, arginine,
# Nearest to had: was, has, were, are, ada, dod, stadtbahn, alanine,
# Nearest to the: his, a, this, mpeg, glas, fricative, mvs, stadtbahn,
# Nearest to one: two, four, three, six, five, seven, fricative, eight,
# Nearest to war: hus, parishes, lysine, barb, africaine, tyrosine, unemployment, modula,
# Nearest to not: it, they, that, zilog, szko, there, which, dod,
# Nearest to was: is, has, by, had, were, portable, fricative, stadtbahn,
# Nearest to system: geotechnical, staking, twh, germanicus, molds, fricative, mpeg, kaliningrad,
# Nearest to only: algebraic, relational, roque, transcribe, oracle, fleetwood, stadtbahn, exec,
# Nearest to he: it, who, and, germanicus, exec, portable, barb, wy,
# Nearest to while: algebraic, zilog, striping, ims, and, baffin, clitoris, algol,
# Average loss at step  22000 :  8.681157821297646
# Average loss at step  24000 :  7.937078909754753
# Average loss at step  26000 :  7.5101043242216114
# Average loss at step  28000 :  7.0867426453828815
# Average loss at step  30000 :  6.6195055005550385
# Nearest to than: bourdieu, modula, stadtbahn, strolling, eight, for, dod, prespa,
# Nearest to nine: eight, seven, five, six, four, zero, three, fricative,
# Nearest to of: in, and, prespa, for, miniszt, glas, fricative, goitre,
# Nearest to known: such, well, greenhouses, mixers, tahitian, endogenous, seen, threonine,
# Nearest to seven: four, eight, six, five, nine, three, one, zero,
# Nearest to but: dod, and, fricative, glas, which, gkos, mushrooms, algebraic,
# Nearest to had: has, was, were, have, ada, stadtbahn, dod, alanine,
# Nearest to the: his, this, a, mpeg, their, glas, fricative, miniszt,
# Nearest to one: two, four, seven, six, five, three, eight, fricative,
# Nearest to war: hus, parishes, prespa, hwv, lysine, africaine, rietveld, barb,
# Nearest to not: it, they, histogram, ravel, that, there, which, to,
# Nearest to was: is, were, has, had, by, but, portable, fricative,
# Nearest to system: geotechnical, hwv, auratus, staking, germanicus, molds, twh, fricative,
# Nearest to only: algebraic, hwv, relational, roque, oracle, exec, fleetwood, stadtbahn,
# Nearest to he: it, she, who, they, there, germanicus, and, wy,
# Nearest to while: algebraic, zilog, mos, striping, and, algol, baffin, of,
# Average loss at step  32000 :  6.57798234808445
# Average loss at step  34000 :  6.402767741560936
# Average loss at step  36000 :  6.117874363780022
# Average loss at step  38000 :  6.042500096917152
# Average loss at step  40000 :  5.998594203472138
# Nearest to than: bourdieu, or, impressionism, modula, for, stadtbahn, dod, strolling,
# Nearest to nine: eight, seven, five, six, four, three, zero, hyi,
# Nearest to of: in, prespa, for, landesverband, hyi, and, fricative, miniszt,
# Nearest to known: well, such, greenhouses, seen, mixers, tahitian, endogenous, threonine,
# Nearest to seven: eight, five, six, four, nine, three, zero, one,
# Nearest to but: and, hyi, landesverband, glas, dod, fricative, khanty, landsmannschaft,
# Nearest to had: has, was, were, have, stadtbahn, dod, are, ada,
# Nearest to the: landesverband, his, mpeg, this, hyi, glas, their, its,
# Nearest to one: seven, two, three, four, eight, six, five, fricative,
# Nearest to war: hus, parishes, lysine, hyi, prespa, hwv, hogshead, africaine,
# Nearest to not: they, it, histogram, ravel, to, also, there, we,
# Nearest to was: is, has, were, had, by, but, portable, fricative,
# Nearest to system: geotechnical, hwv, auratus, staking, germanicus, molds, kaliningrad, twh,
# Nearest to only: algebraic, hwv, hyi, landesverband, landsmannschaft, relational, roque, oracle,
# Nearest to he: it, she, who, they, there, which, this, impressionism,
# Nearest to while: algebraic, but, zilog, landesverband, algol, striping, and, baffin,
# Average loss at step  42000 :  5.8445031741857525
# Average loss at step  44000 :  5.724084567189217
# Average loss at step  46000 :  5.630838896036148
# Average loss at step  48000 :  5.459732084870338
# Average loss at step  50000 :  5.134760797858238
# Nearest to than: bourdieu, or, modula, impressionism, nine, stadtbahn, hyi, pdp,
# Nearest to nine: eight, seven, six, five, four, three, hyi, zero,
# Nearest to of: prespa, hyi, landesverband, fricative, goitre, miniszt, glas, and,
# Nearest to known: well, such, seen, greenhouses, endogenous, mixers, tahitian, threonine,
# Nearest to seven: six, four, eight, five, nine, three, one, zero,
# Nearest to but: hyi, however, fricative, landesverband, glas, modula, landsmannschaft, algebraic,
# Nearest to had: has, have, was, were, stadtbahn, dod, alanine, amd,
# Nearest to the: its, hyi, landesverband, their, glas, his, a, this,
# Nearest to one: seven, six, four, three, fricative, two, five, miniszt,
# Nearest to war: hus, lysine, parishes, syne, hyi, hogshead, hwv, prespa,
# Nearest to not: they, it, histogram, ravel, we, also, to, often,
# Nearest to was: is, were, has, had, by, but, portable, fricative,
# Nearest to system: geotechnical, hwv, molds, auratus, staking, germanicus, votive, kaliningrad,
# Nearest to only: algebraic, hyi, hwv, landsmannschaft, landesverband, relational, oracle, roque,
# Nearest to he: it, she, they, who, there, impressionism, which, but,
# Nearest to while: but, algebraic, landesverband, algol, zilog, subgenus, striping, of,
# Average loss at step  52000 :  5.3294042525291445
# Average loss at step  54000 :  5.390852270007134
# Average loss at step  56000 :  5.316103797912597
# Average loss at step  58000 :  5.281067482352257
# Average loss at step  60000 :  5.038173010587692
# Nearest to than: or, bourdieu, cccc, modula, impressionism, wolfhounds, stadtbahn, hyi,
# Nearest to nine: seven, eight, six, four, five, zero, three, hyi,
# Nearest to of: in, prespa, hyi, landesverband, fricative, miniszt, glas, for,
# Nearest to known: well, such, seen, greenhouses, mixers, endogenous, tahitian, threonine,
# Nearest to seven: four, six, five, eight, nine, three, zero, two,
# Nearest to but: however, hyi, fricative, landesverband, modula, glas, cccc, landsmannschaft,
# Nearest to had: has, have, was, were, stadtbahn, novorossiysk, dod, became,
# Nearest to the: their, its, his, landesverband, hyi, glas, fricative, mpeg,
# Nearest to one: two, three, four, seven, five, six, miniszt, fricative,
# Nearest to war: hus, lysine, hwv, parishes, hyi, syne, recalled, jewell,
# Nearest to not: they, it, we, histogram, ravel, often, also, which,
# Nearest to was: is, had, were, has, by, portable, fricative, histogram,
# Nearest to system: molds, geotechnical, auratus, hwv, staking, fricative, germanicus, votive,
# Nearest to only: hwv, algebraic, hyi, landesverband, landsmannschaft, roque, oracle, relational,
# Nearest to he: it, she, they, who, there, novorossiysk, wy, hyi,
# Nearest to while: but, algebraic, landesverband, algol, subgenus, when, zilog, novorossiysk,
# Average loss at step  62000 :  5.102459380030632
# Average loss at step  64000 :  5.149083138585091
# Average loss at step  66000 :  4.966776463985443
# Average loss at step  68000 :  4.88084834086895
# Average loss at step  70000 :  4.843403490424156
# Nearest to than: or, bourdieu, cccc, modula, impressionism, dod, stadtbahn, hyi,
# Nearest to nine: eight, seven, six, five, four, three, zero, hyi,
# Nearest to of: prespa, in, including, for, hyi, landesverband, and, goitre,
# Nearest to known: such, well, seen, greenhouses, ingalls, mixers, endogenous, tahitian,
# Nearest to seven: six, eight, four, five, nine, three, zero, hyi,
# Nearest to but: however, and, hyi, which, landesverband, fricative, modula, landsmannschaft,
# Nearest to had: has, have, was, were, became, is, when, while,
# Nearest to the: its, their, his, hyi, this, landesverband, mpeg, a,
# Nearest to one: four, two, six, seven, three, miniszt, hyi, fricative,
# Nearest to war: hogshead, hwv, hus, syne, prespa, hyi, cottage, lysine,
# Nearest to not: it, they, we, histogram, ravel, often, also, nia,
# Nearest to was: is, had, were, has, portable, when, fricative, rium,
# Nearest to system: molds, geotechnical, niggle, auratus, hwv, votive, staking, kaliningrad,
# Nearest to only: algebraic, hwv, hyi, landesverband, landsmannschaft, anh, oracle, relational,
# Nearest to he: it, she, they, there, who, but, and, novorossiysk,
# Nearest to while: but, algebraic, algol, landesverband, when, and, subgenus, gettier,
# Average loss at step  72000 :  4.905080305933953
# Average loss at step  74000 :  4.902288625717163
# Average loss at step  76000 :  4.88037107694149
# Average loss at step  78000 :  4.771680833816529
# Average loss at step  80000 :  5.005643312931061
# Nearest to than: or, bourdieu, cccc, modula, impressionism, dod, wolfhounds, stadtbahn,
# Nearest to nine: eight, seven, six, four, five, three, hyi, fricative,
# Nearest to of: landesverband, prespa, hyi, fricative, abm, sld, goitre, glas,
# Nearest to known: such, well, seen, greenhouses, used, mixers, ingalls, described,
# Nearest to seven: six, eight, four, five, three, nine, hyi, one,
# Nearest to but: however, and, hyi, landesverband, modula, fricative, algebraic, landsmannschaft,
# Nearest to had: has, have, was, were, became, novorossiysk, while, stadtbahn,
# Nearest to the: landesverband, its, hyi, mpeg, glas, fricative, hwv, their,
# Nearest to one: seven, six, two, miniszt, four, fricative, three, hyi,
# Nearest to war: hus, cottage, hwv, hogshead, hyi, syne, prespa, recalled,
# Nearest to not: they, we, histogram, it, to, ravel, often, nia,
# Nearest to was: is, had, were, has, became, portable, but, fricative,
# Nearest to system: molds, geotechnical, niggle, auratus, votive, staking, hwv, fricative,
# Nearest to only: hwv, hyi, landesverband, algebraic, landsmannschaft, anh, oracle, roque,
# Nearest to he: she, it, they, who, there, but, novorossiysk, and,
# Nearest to while: but, when, algebraic, algol, and, landesverband, although, gettier,
# Average loss at step  82000 :  4.978968981862068
# Average loss at step  84000 :  4.967715093016625
# Average loss at step  86000 :  4.869758800983429
# Average loss at step  88000 :  4.603564547419548
# Average loss at step  90000 :  4.876301184773445
# Nearest to than: or, bourdieu, and, cccc, modula, nine, but, kiwi,
# Nearest to nine: eight, seven, six, five, four, three, rajonas, zero,
# Nearest to of: hyi, rajonas, prespa, loris, landesverband, glas, goitre, danio,
# Nearest to known: such, well, seen, used, greenhouses, available, described, mixers,
# Nearest to seven: six, eight, four, five, three, nine, rajonas, two,
# Nearest to but: however, hyi, and, rajonas, landesverband, modula, fricative, loris,
# Nearest to had: has, have, was, were, became, novorossiysk, stadtbahn, while,
# Nearest to the: this, rajonas, landesverband, hyi, glas, kinderhook, his, its,
# Nearest to one: two, six, rajonas, four, seven, three, miniszt, fricative,
# Nearest to war: hus, cottage, hogshead, hyi, syne, hwv, prespa, hunchback,
# Nearest to not: histogram, they, it, we, often, ravel, still, usually,
# Nearest to was: is, were, had, has, became, portable, alanine, when,
# Nearest to system: molds, geotechnical, auratus, auras, staking, niggle, hwv, fricative,
# Nearest to only: hwv, rajonas, hyi, landesverband, algebraic, landsmannschaft, anh, loris,
# Nearest to he: she, it, they, there, who, then, but, novorossiysk,
# Nearest to while: but, when, algol, although, landesverband, algebraic, gettier, loris,
# Average loss at step  92000 :  5.002224568963051
# Average loss at step  94000 :  4.895537791967392
# Average loss at step  96000 :  4.8553068315982815
# Average loss at step  98000 :  4.841165178537369
# Average loss at step  100000 :  4.751809794425965
# Nearest to than: or, bourdieu, but, cccc, kiwi, modula, dod, and,
# Nearest to nine: eight, six, seven, four, five, rajonas, zero, rstenberg,
# Nearest to of: rstenberg, hyi, merlot, landesverband, danio, loris, prespa, rajonas,
# Nearest to known: well, such, seen, used, greenhouses, available, mixers, described,
# Nearest to seven: eight, six, four, five, three, nine, zero, rajonas,
# Nearest to but: however, and, rstenberg, hyi, safl, rajonas, dicrostonyx, landesverband,
# Nearest to had: has, have, was, were, became, novorossiysk, stadtbahn, anh,
# Nearest to the: their, rajonas, its, safl, rstenberg, hyi, kinderhook, landesverband,
# Nearest to one: two, seven, three, four, six, eight, rajonas, five,
# Nearest to war: hus, hyi, cottage, hwv, prespa, hogshead, hunchback, syne,
# Nearest to not: histogram, often, ravel, it, they, we, still, usually,
# Nearest to was: is, had, has, were, became, safl, when, taklamakan,
# Nearest to system: molds, auratus, geotechnical, staking, hwv, auras, twh, fricative,
# Nearest to only: ctus, rajonas, hwv, hyi, landesverband, nine, landsmannschaft, safl,
# Nearest to he: she, it, they, who, there, but, novorossiysk, then,
# Nearest to while: but, when, although, dicrostonyx, safl, algol, rstenberg, algebraic,
# Average loss at step  102000 :  4.7187223357558254
# Average loss at step  104000 :  4.818322242259979
# Average loss at step  106000 :  4.438746344685555
# Average loss at step  108000 :  4.484707468748093
# Average loss at step  110000 :  4.6573026995658875
# Nearest to than: or, bourdieu, kiwi, cccc, modula, dod, windmill, but,
# Nearest to nine: eight, six, seven, four, five, mjt, rajonas, three,
# Nearest to of: rstenberg, mjw, spitz, prespa, including, hyi, loris, merlot,
# Nearest to known: such, well, used, seen, greenhouses, available, described, mixers,
# Nearest to seven: six, eight, four, five, three, nine, rajonas, mjw,
# Nearest to but: however, and, hyi, safl, rstenberg, rajonas, mjw, dod,
# Nearest to had: has, have, was, were, became, anh, novorossiysk, stadtbahn,
# Nearest to the: its, their, rajonas, landesverband, safl, mjw, kinderhook, rstenberg,
# Nearest to one: rajonas, safl, miniszt, audita, rstenberg, fricative, loris, pngimage,
# Nearest to war: hus, cottage, hyi, prespa, dramatists, hwv, syne, hogshead,
# Nearest to not: often, histogram, it, usually, we, still, ravel, they,
# Nearest to was: is, had, were, has, became, when, taklamakan, safl,
# Nearest to system: molds, geotechnical, auratus, hwv, auras, staking, fricative, twh,
# Nearest to only: ctus, rajonas, landesverband, hyi, hwv, landsmannschaft, mjw, safl,
# Nearest to he: she, it, they, there, who, but, novorossiysk, mirabeau,
# Nearest to while: but, although, when, dicrostonyx, safl, algol, rstenberg, landesverband,
# Average loss at step  112000 :  4.622876326084137
# Average loss at step  114000 :  4.58407290995121
# Average loss at step  116000 :  4.603886068940163
# Average loss at step  118000 :  4.811164516568184
# Average loss at step  120000 :  4.647951827764511
# Nearest to than: or, bourdieu, but, dod, modula, windmill, cccc, kiwi,
# Nearest to nine: eight, seven, six, four, five, rajonas, mjt, hyi,
# Nearest to of: rstenberg, prespa, mammuthus, mjw, hyi, landesverband, vec, spitz,
# Nearest to known: such, used, well, seen, mondegreen, available, greenhouses, mixers,
# Nearest to seven: eight, six, five, four, nine, three, rajonas, mjw,
# Nearest to but: however, although, hyi, rstenberg, safl, rajonas, mjw, and,
# Nearest to had: has, have, was, were, became, novorossiysk, anh, stadtbahn,
# Nearest to the: its, rajonas, safl, hyi, landesverband, kinderhook, rstenberg, audita,
# Nearest to one: rajonas, safl, audita, miniszt, rstenberg, fricative, mjt, loris,
# Nearest to war: dramatists, cottage, prespa, syne, hus, antlia, hyi, bible,
# Nearest to not: usually, histogram, often, vec, ravel, we, still, it,
# Nearest to was: is, had, were, became, has, when, safl, taklamakan,
# Nearest to system: molds, auratus, hwv, geotechnical, fricative, shaku, auras, niggle,
# Nearest to only: ctus, rajonas, hwv, hyi, landesverband, mjw, landsmannschaft, safl,
# Nearest to he: she, it, they, there, who, novorossiysk, but, vec,
# Nearest to while: although, but, when, dicrostonyx, safl, algol, rstenberg, landesverband,
# Average loss at step  122000 :  4.5974390971660615
# Average loss at step  124000 :  4.626430645227432
# Average loss at step  126000 :  4.636729281902313
# Average loss at step  128000 :  4.613240068793297
# Average loss at step  130000 :  4.635636159181595
# Nearest to than: or, but, bourdieu, dod, and, windmill, cccc, modula,
# Nearest to nine: eight, seven, five, four, six, rajonas, mjt, mjw,
# Nearest to of: rstenberg, in, prespa, mammuthus, including, alces, hyi, vec,
# Nearest to known: such, used, well, seen, mondegreen, available, greenhouses, described,
# Nearest to seven: four, eight, five, six, nine, three, rajonas, mjw,
# Nearest to but: however, and, hyi, rstenberg, safl, rajonas, alces, although,
# Nearest to had: has, have, was, were, became, novorossiysk, anh, stadtbahn,
# Nearest to the: its, their, his, rajonas, safl, this, landesverband, hyi,
# Nearest to one: rajonas, two, miniszt, safl, fricative, kirchenmusik, loris, seven,
# Nearest to war: prespa, hus, dramatists, syne, hyi, cottage, hwv, antlia,
# Nearest to not: usually, histogram, often, it, vec, still, ravel, to,
# Nearest to was: is, had, became, were, has, when, safl, pngimage,
# Nearest to system: molds, auratus, hwv, fricative, geotechnical, shaku, systems, auras,
# Nearest to only: ctus, rajonas, hwv, landesverband, hyi, mjw, landsmannschaft, safl,
# Nearest to he: she, it, they, there, who, but, novorossiysk, then,
# Nearest to while: although, but, when, dicrostonyx, however, rstenberg, safl, algol,
# Average loss at step  132000 :  4.544413853287697
# Average loss at step  134000 :  4.621082831382751
# Average loss at step  136000 :  4.591047001838684
# Average loss at step  138000 :  4.518938992261886
# Average loss at step  140000 :  4.575271430373192
# Nearest to than: or, but, and, bourdieu, dod, modula, cccc, windmill,
# Nearest to nine: eight, seven, six, five, four, zero, three, mjt,
# Nearest to of: rstenberg, vec, mjw, hyi, prespa, teimanim, kirchenmusik, mammuthus,
# Nearest to known: used, such, well, seen, available, mondegreen, described, greenhouses,
# Nearest to seven: six, eight, four, five, nine, three, rajonas, mjt,
# Nearest to but: however, and, hyi, rstenberg, reginae, although, rajonas, safl,
# Nearest to had: has, have, was, were, anh, novorossiysk, stadtbahn, reginae,
# Nearest to the: its, rajonas, this, safl, their, hyi, landesverband, victoriae,
# Nearest to one: rajonas, audita, safl, kirchenmusik, fricative, loris, miniszt, rstenberg,
# Nearest to war: dramatists, prespa, cottage, recalled, syne, hyi, hus, antlia,
# Nearest to not: usually, often, histogram, it, vec, still, ravel, hwv,
# Nearest to was: is, had, were, has, became, safl, loris, pngimage,
# Nearest to system: molds, systems, auratus, hwv, geotechnical, fricative, shaku, victoriae,
# Nearest to only: ctus, rajonas, hyi, mjw, landesverband, victoriae, hwv, landsmannschaft,
# Nearest to he: she, it, they, there, who, but, then, alces,
# Nearest to while: although, when, reginae, but, dicrostonyx, rstenberg, safl, victoriae,
# Average loss at step  142000 :  4.57356060385704
# Average loss at step  144000 :  4.61061202776432
# Average loss at step  146000 :  4.421512804508209
# Average loss at step  148000 :  4.472627346873283
# Average loss at step  150000 :  4.530129937410354
# Nearest to than: or, bourdieu, and, dod, modula, but, cccc, hyi,
# Nearest to nine: eight, seven, six, five, four, three, rajonas, mjt,
# Nearest to of: rstenberg, mjw, mammuthus, hyi, kirchenmusik, alces, landesverband, prespa,
# Nearest to known: used, such, well, seen, mondegreen, available, described, greenhouses,
# Nearest to seven: eight, six, four, nine, five, three, rajonas, mjw,
# Nearest to but: however, and, although, reginae, dasyprocta, safl, hyi, rstenberg,
# Nearest to had: has, have, was, were, anh, novorossiysk, stadtbahn, having,
# Nearest to the: its, rajonas, kinderhook, dasyprocta, landesverband, safl, victoriae, mjw,
# Nearest to one: rajonas, safl, audita, dasyprocta, kirchenmusik, rstenberg, fricative, dddddd,
# Nearest to war: dramatists, cottage, prespa, bible, syne, recalled, hus, hyi,
# Nearest to not: usually, often, histogram, still, vec, it, hwv, absalom,
# Nearest to was: is, had, became, has, were, when, safl, although,
# Nearest to system: molds, systems, auratus, hwv, fricative, geotechnical, shaku, victoriae,
# Nearest to only: ctus, rajonas, absalom, landesverband, hyi, victoriae, mjw, hwv,
# Nearest to he: she, it, they, there, who, novorossiysk, but, alces,
# Nearest to while: although, reginae, when, but, victoriae, safl, dicrostonyx, rstenberg,
# Average loss at step  152000 :  4.541546965956688
# Average loss at step  154000 :  4.522750314593315
# Average loss at step  156000 :  4.507714319705963
# Average loss at step  158000 :  4.525037831544876
# Average loss at step  160000 :  4.566812612056732
# Nearest to than: or, but, bourdieu, dod, windmill, modula, hyi, cccc,
# Nearest to nine: eight, seven, six, five, four, mjt, rajonas, rstenberg,
# Nearest to of: rstenberg, prespa, hyi, mjw, reginae, including, landesverband, mammuthus,
# Nearest to known: used, such, well, seen, mondegreen, described, available, regarded,
# Nearest to seven: six, eight, five, four, nine, three, rajonas, mjw,
# Nearest to but: however, and, although, dasyprocta, hyi, reginae, safl, rstenberg,
# Nearest to had: has, have, was, were, anh, stadtbahn, having, novorossiysk,
# Nearest to the: its, their, rajonas, victoriae, dasyprocta, kinderhook, safl, this,
# Nearest to one: rajonas, rstenberg, two, dasyprocta, safl, miniszt, kirchenmusik, audita,
# Nearest to war: dramatists, cottage, prespa, bible, syne, hunchback, hyi, pared,
# Nearest to not: histogram, usually, often, still, vec, absalom, hwv, ravel,
# Nearest to was: is, had, became, has, were, when, although, safl,
# Nearest to system: molds, systems, auratus, hwv, geotechnical, fricative, shaku, vax,
# Nearest to only: ctus, rajonas, victoriae, absalom, landsmannschaft, landesverband, hyi, hwv,
# Nearest to he: she, it, they, there, who, novorossiysk, but, never,
# Nearest to while: although, reginae, but, when, dicrostonyx, safl, victoriae, rstenberg,
# Average loss at step  162000 :  4.580643556237221
# Average loss at step  164000 :  4.557468195438385
# Average loss at step  166000 :  4.516463719487191
# Average loss at step  168000 :  4.310999434232712
# Average loss at step  170000 :  4.5365182700157165
# Nearest to than: or, bourdieu, but, dod, modula, and, hyi, windmill,
# Nearest to nine: eight, seven, six, five, zero, four, rajonas, mjt,
# Nearest to of: rstenberg, vec, mammuthus, mjw, including, hyi, prespa, kirchenmusik,
# Nearest to known: used, such, seen, well, described, mondegreen, available, regarded,
# Nearest to seven: six, eight, five, four, zero, three, nine, rajonas,
# Nearest to but: however, and, although, hyi, dasyprocta, reginae, rstenberg, safl,
# Nearest to had: has, have, was, were, anh, stadtbahn, mjw, having,
# Nearest to the: dasyprocta, rajonas, glas, hyi, victoriae, rstenberg, mjw, landesverband,
# Nearest to one: two, seven, rajonas, eight, safl, four, kirchenmusik, dasyprocta,
# Nearest to war: dramatists, pared, prespa, cottage, syne, recalled, hyi, antlia,
# Nearest to not: usually, often, histogram, still, vec, it, absalom, hwv,
# Nearest to was: is, were, had, became, has, when, although, safl,
# Nearest to system: systems, molds, auratus, geotechnical, hwv, fricative, shaku, vax,
# Nearest to only: ctus, rajonas, victoriae, landesverband, absalom, hyi, landsmannschaft, safl,
# Nearest to he: she, it, they, there, who, but, never, novorossiysk,
# Nearest to while: although, when, reginae, but, though, however, victoriae, dicrostonyx,
# Average loss at step  172000 :  4.4952351363897325
# Average loss at step  174000 :  4.449723875522613
# Average loss at step  176000 :  5.320539345026016
# Average loss at step  178000 :  4.455196234822274
# Average loss at step  180000 :  4.496564276099205
# Nearest to than: or, but, bourdieu, and, dod, modula, hyi, windmill,
# Nearest to nine: eight, six, seven, three, five, thibetanus, mjt, four,
# Nearest to of: rstenberg, mjw, mammuthus, hyi, vec, including, prespa, reginae,
# Nearest to known: used, such, well, seen, mondegreen, described, available, regarded,
# Nearest to seven: eight, six, four, five, three, nine, mjw, rajonas,
# Nearest to but: however, and, although, hyi, reginae, dasyprocta, while, rstenberg,
# Nearest to had: has, have, was, were, anh, having, is, stadtbahn,
# Nearest to the: rajonas, dasyprocta, landesverband, safl, hyi, kinderhook, rstenberg, victoriae,
# Nearest to one: thibetanus, two, rajonas, kirchenmusik, dasyprocta, miniszt, rstenberg, eight,
# Nearest to war: dramatists, cottage, pared, prespa, syne, thibetanus, hyi, recalled,
# Nearest to not: usually, histogram, still, often, absalom, vec, almost, hwv,
# Nearest to was: is, had, were, has, became, although, safl, victoriae,
# Nearest to system: systems, molds, auratus, hwv, geotechnical, fricative, shaku, victoriae,
# Nearest to only: ctus, rajonas, victoriae, absalom, landesverband, hyi, safl, landsmannschaft,
# Nearest to he: she, it, they, there, who, this, but, alces,
# Nearest to while: although, when, reginae, however, but, though, dicrostonyx, victoriae,
# Average loss at step  182000 :  4.48927164041996
# Average loss at step  184000 :  4.557381262540817
# Average loss at step  186000 :  4.5020354918241505
# Average loss at step  188000 :  4.521327016830444
# Average loss at step  190000 :  4.552646766424179
# Nearest to than: or, but, bourdieu, dod, modula, hyi, nine, windmill,
# Nearest to nine: eight, seven, six, four, five, callithrix, mjt, rajonas,
# Nearest to of: rstenberg, cebus, including, mammuthus, callithrix, prespa, spitz, mjw,
# Nearest to known: used, such, well, seen, described, mondegreen, available, regarded,
# Nearest to seven: eight, six, five, nine, four, callithrix, mjw, rajonas,
# Nearest to but: however, although, callithrix, and, hyi, reginae, wct, cebus,
# Nearest to had: has, have, was, were, having, anh, stadtbahn, gettier,
# Nearest to the: dasyprocta, rajonas, landesverband, hyi, thibetanus, rstenberg, mjt, kinderhook,
# Nearest to one: two, four, six, rajonas, three, dasyprocta, thibetanus, miniszt,
# Nearest to war: dramatists, cottage, prespa, pared, thibetanus, hyi, recalled, antlia,
# Nearest to not: usually, still, histogram, almost, vec, wct, often, absalom,
# Nearest to was: is, had, has, became, were, when, although, safl,
# Nearest to system: systems, molds, auratus, hwv, geotechnical, fricative, shaku, wct,
# Nearest to only: callithrix, ctus, rajonas, victoriae, absalom, landesverband, hyi, safl,
# Nearest to he: she, it, they, there, who, but, never, novorossiysk,
# Nearest to while: although, when, reginae, though, however, dicrostonyx, victoriae, callithrix,
# Average loss at step  192000 :  4.42365640258789
# Average loss at step  194000 :  4.353319880366326
# Average loss at step  196000 :  4.321513415455819
# Average loss at step  198000 :  4.477201992630959
# Average loss at step  200000 :  4.490687474489212
# Nearest to than: or, but, bourdieu, and, dod, windmill, much, even,
# Nearest to nine: eight, seven, six, five, thibetanus, four, callithrix, mjt,
# Nearest to of: cebus, rstenberg, mjw, mammuthus, hyi, callithrix, prespa, thibetanus,
# Nearest to known: used, such, seen, well, described, mondegreen, regarded, available,
# Nearest to seven: six, eight, five, four, three, nine, rajonas, callithrix,
# Nearest to but: however, although, and, callithrix, hyi, though, reginae, cebus,
# Nearest to had: has, have, was, were, having, anh, stadtbahn, gettier,
# Nearest to the: rajonas, dasyprocta, safl, victoriae, thibetanus, wct, landesverband, hyi,
# Nearest to one: rajonas, thibetanus, safl, two, six, miniszt, loris, kirchenmusik,
# Nearest to war: dramatists, pared, cottage, prespa, antlia, recalled, hyi, roque,
# Nearest to not: usually, histogram, still, now, vec, wct, almost, absalom,
# Nearest to was: is, had, became, has, were, although, when, safl,
# Nearest to system: systems, molds, auratus, geotechnical, hwv, fricative, shaku, technology,
# Nearest to only: victoriae, ctus, rajonas, callithrix, absalom, landesverband, hwv, safl,
# Nearest to he: she, it, they, there, who, never, wct, novorossiysk,
# Nearest to while: although, when, though, however, reginae, but, dicrostonyx, victoriae,

# %%
  # Step 6: Visualize the embeddings.

  # pylint: disable=missing-docstring
  # Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
      x, y = low_dim_embs[i, :]
      plt.scatter(x, y)
      plt.annotate(
          label,
          xy=(x, y),
          xytext=(5, 2),
          textcoords='offset points',
          ha='right',
          va='bottom')

    plt.savefig(filename)

try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(
        perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(),
                                                        'tsne.png'))

except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)
